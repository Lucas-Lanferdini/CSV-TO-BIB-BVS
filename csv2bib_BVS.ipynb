# %%
import os

from math import isnan
from sys import argv, exit

import pandas as pd


class BibEntry(object):
    def __init__(self):
        self.ID= None
        self.Title = None
        self.Authors = None
        self.Source = None
        self.Journal = None
        self.Database = None
        self.Type = None
        self.Language = None
        self.Publicationyear = None
        self.Descriptor = None
        self.Keyword= None
        self.Publication_Country= None
        self.Fulltext_URL= None
        self.Abstract= None
        self.Entry_Date= None
        self.Volume_number= None
        self.Issue_number= None
        self.DOI= None
        self.ISSN= None
        self.Accession_number= None
        self.PMCID= None



    def generate_bib(self, header_id: str) -> str:
        """
        Based on its members, returns
        a string in .bib format entry
        """
        header = "@INPROCEEDINGS{"+header_id+",\n\t"
        authors = "author={"+self.Authors+"},\n\t"
        Journal = "booktitle={"+str(self.Source)+"},\n\t"
        title = "title={"+self.Title+"},\n\t"
        Publicationyear = "year={"+str(self.Publicationyear)+"},\n\t"
        Volume = "volume={"+str(self.Volume_number)+"},\n\t"
        Number = "number={"+ ''+"},\n\t"
        pages = "pages={"+'' +"},\n\t"
        Abstract = "abstract={"+str(self.Abstract)+"},\n\t"
        Keyword = "keywords={"+str(self.Keyword)+"},\n\t"
        DOI = "doi={"+str(self.DOI)+"},\n\t"
        ISSN = "ISSN={"+str(self.ISSN)+"},\n\t"
        PMCID = "month={"+'' +"},\n}\n\n"
        return header+authors+Journal+title+Publicationyear+Volume+Number+pages+Keyword+Abstract+DOI+ISSN+PMCID


def _get_bibentries(filepath: str) -> list:
    if os.path.exists("/content/export.csv"):
        bibentries = []
        springer_csv = pd.read_csv("/content/export.csv")
        springer_csv.fillna('', inplace=True)
        display(springer_csv)
        for index, row in springer_csv.iterrows():
            bibentry = BibEntry()
            bibentry.ID = row['ID']
            bibentry.Title = row['Title']
            bibentry.Authors = row['Authors']
            bibentry.Source = row['Source']
            bibentry.Journal = row['Journal']
            bibentry.Database = row['Database']
            bibentry.Type = row['Type']
            bibentry.Language = row['Language']
            bibentry.Publicationyear = row['Publication year']
            bibentry.Descriptor = row['Descriptor(s)']
            bibentry.Keyword = row['Keyword(s)']
            bibentry.Publication_Country = row['Publication Country']
            bibentry.Fulltext_URL = row['Fulltext URL']
            bibentry.Abstract = row[' Abstract']
            bibentry.Entry_Date = row['Entry Date']
            bibentry.Volume_number = row['Volume number']
            bibentry.Issue_number = row['Issue number']
            bibentry.DOI = row['DOI']
            bibentry.ISSN = row['ISSN']
            bibentry.Accession_number = row['Accession number']
            bibentry.PMCID = row['PMCID']


            bibentries.append(bibentry.generate_bib(str(index)))
        return bibentries
    else:
        print("{0} not found!".format("/content/export.csv"))
        return []


def convert_csv2bib(filepath: str) -> bool:
    """
    It converts a .csv in SpringerLink format
    to a valid .bib with the same name, just
    changing extension.

    ATTENTION: if a .bib file with the same name aready exists,
    it will be appended!

    :param filepath: a path to a .csv file
    :return: True if .bib file was created, False otherwise.
    """
    bibentries = _get_bibentries(filepath)
    bibfile = filepath.split(".")[0] + ".bib"
    for bib in bibentries:
        with open(bibfile, 'a') as f:
            f.write(bib)


if __name__ == "__main__":
    try:
        print(argv[1])
        filepath = argv[1]
    except:
        print("Usage: python springer_csv2bib <filepath.csv>")
        exit(0)
    convert_csv2bib(filepath=argv[1])
# Out:
# -f
#                ID                                              Title  \
# 0    mdl-38426589  Weishaar's classification system for nodal met...
# 1    mdl-38390266  Brain tumor classification from MRI scans: a f...
# 2    mdl-38369844  Self-attention-based generative adversarial ne...
# 3    mdl-38402382  Advanced gastrointestinal stromal tumor: relia...
# 4    mdl-38407266  Molecular classification and tumor microenviro...
# ..            ...                                                ...
# 784  mdl-24120084  Zonal NePhRO scoring system: a superior renal ...
# 785  mdl-24199963  Tumor classification in well-differentiated th...
# 786  mdl-24211363  Efficient identification of miRNAs for classif...
# 787  mdl-24211962  Feature selection using mutual information bas...
# 788  mdl-24212037  Tumor classification based on orthogonal linea...
#
#                                                Authors  \
# 0    Stefanello, Damiano; Gariboldi, Elisa M; Borac...
# 1    Ullah, Muhammad Sami; Khan, Muhammad Attique; ...
# 2    S, Senthil Pandi; A, Senthilselvi; T, Kumaragu...
# 3    Ran, Pan; Tan, Tao; Li, Jinjin; Yang, Hao; Li,...
# 4    Qin, Sen; Xu, Yawei; Yu, Shimiao; Han, Wencong...
# ..                                                 ...
# 784  Hakky, Tariq S; Baumgarten, Adam S; Allen, Bry...
# 785  Maniakas, Anastasios; Forest, Veronique-Isabel...
# 786  Søkilde, Rolf; Vincent, Martin; Møller, Anne K...
# 787                             Sun, Lin; Xu, Jiucheng
# 788                        Wang, Huiya; Zhang, Shanwen
#
#                                               Source                 Journal  \
# 0                     J Vet Intern Med;2024 Mar 01.         J Vet Intern Med
# 1                    Front Oncol;14: 1335740, 2024.              Front Oncol
# 2         Electromagn Biol Med;: 1-15, 2024 Feb 18.     Electromagn Biol Med
# 3               BMC Cancer;24(1): 264, 2024 Feb 24.               BMC Cancer
# 4                              Elife;122024 Feb 26.                    Elife
# ..                                               ...                     ...
# 784  Clin Genitourin Cancer;12(1): e13-8, 2014 Feb.   Clin Genitourin Cancer
# 785                 Thyroid;24(4): 671-4, 2014 Apr.                  Thyroid
# 786            J Mol Diagn;16(1): 106-15, 2014 Jan.              J Mol Diagn
# 787           Biomed Mater Eng;24(1): 763-70, 2014.         Biomed Mater Eng
# 788         Biomed Mater Eng;24(1): 1399-405, 2014.         Biomed Mater Eng
#
#     Database     Type Language  Publication year  \
# 0    MEDLINE  article       en              2024
# 1    MEDLINE  article       en              2024
# 2    MEDLINE  article       en              2024
# 3    MEDLINE  article       en              2024
# 4    MEDLINE  article       en              2024
# ..       ...      ...      ...               ...
# 784  MEDLINE  article       en              2014
# 785  MEDLINE  article       en              2014
# 786  MEDLINE  article       en              2014
# 787  MEDLINE  article       en              2014
# 788  MEDLINE  article       en              2014
#
#                                          Descriptor(s)  ...  \
# 0                                                       ...
# 1                                                       ...
# 2                                                       ...
# 3    Tumores do Estroma Gastrointestinal; Humanos; ...  ...
# 4    Neoplasias das Glândulas Suprarrenais; Feocrom...  ...
# ..                                                 ...  ...
# 784  Carcinoma de Células Renais/classificação; Neo...  ...
# 785  Biópsia de Linfonodo Sentinela/métodos; Neopla...  ...
# 786  MicroRNAs/genética; Técnicas de Diagnóstico Mo...  ...
# 787  Perfilação da Expressão Gênica; Neoplasias/cla...  ...
# 788  Análise Discriminante; Leucemia/diagnóstico; N...  ...
#
#     Publication Country                                       Fulltext URL  \
# 0                    US              https://dx.doi.org/10.1111/jvim.16997
# 1                    CH  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...
# 2                    GB   https://dx.doi.org/10.1080/15368378.2024.2312363
# 3                    GB  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...
# 4                    GB             https://dx.doi.org/10.7554/eLife.87586
# ..                  ...                                                ...
# 784                  US      https://dx.doi.org/10.1016/j.clgc.2013.07.009
# 785                  US           https://dx.doi.org/10.1089/thy.2013.0160
# 786                  US    https://dx.doi.org/10.1016/j.jmoldx.2013.10.001
# 787                  NL              https://dx.doi.org/10.3233/BME-130865
# 788                  NL              https://dx.doi.org/10.3233/BME-130944
#
#                                               Abstract  Entry Date  \
# 0    BACKGROUND: The therapeutic role and prognosti...  20240301.0
# 1    Brain tumor classification is one of the most ...  20240223.0
# 2    This paper proposes a novel approach, BTC-SAGA...  20240219.0
# 3    AIM: Patients with advanced gastrointestinal s...  20240224.0
# 4    Pheochromocytomas (PCCs) are rare neuroendocri...  20240226.0
# ..                                                 ...         ...
# 784  BACKGROUND: Since the advent of the first stan...  20131015.0
# 785  BACKGROUND: Predicting locoregional metastasis...  20131109.0
# 786  Carcinomas of unknown primary origin constitut...  20131112.0
# 787  Feature selection is a key problem in tumor cl...  20131112.0
# 788  Gene expression profiles have great potential ...  20131112.0
#
#     Volume number Issue number                            DOI       ISSN  \
# 0                                          10.1111/jvim.16997  1939-1676
# 1              14                   10.3389/fonc.2024.1335740  2234-943X
# 2                               10.1080/15368378.2024.2312363  1536-8386
# 3              24            1     10.1186/s12885-024-11930-6  1471-2407
# 4              12                         10.7554/eLife.87586  2050-084X
# ..            ...          ...                            ...        ...
# 784            12            1     10.1016/j.clgc.2013.07.009  1938-0682
# 785            24            4          10.1089/thy.2013.0160  1557-9077
# 786            16            1   10.1016/j.jmoldx.2013.10.001  1943-7811
# 787            24            1             10.3233/BME-130865  1878-3619
# 788            24            1             10.3233/BME-130944  1878-3619
#
#     Accession number PMCID
# 0
# 1
# 2
# 3
# 4
# ..               ...   ...
# 784
# 785
# 786
# 787
# 788
#
# [789 rows x 21 columns]
